# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import datetime

# %%
# get the sum of all the deaths 
# get the sum of cured patiets of aruachal pradesh regio
# get the data of ihar regio withi 05-02-2021 ad this 10-03-2021
# get the data of a 10-04-2020 of all the regios

# %%
covid_df = pd.read_csv("/content/sample_data/COVID-19 Cases(14-09-2022).csv")

# %%
covid_df.head(5)
# Out:
#    S. No.        Date Region  Confirmed Cases  Active Cases  Cured/Discharged  \
# 0       1  01-01-1970  India         34697860       91456.0        34130768.0
# 1       2  21-12-2014  India         34703644       88993.0        34138763.0
# 2       3  21-12-2015  India         34710628       87562.0        34146931.0
# 3       4  12-03-2020  India               74          71.0               3.0
# 4       5  13-03-2020  India               75          71.0               3.0
#
#       Death
# 0  475636.0
# 1  475888.0
# 2  476135.0
# 3       0.0
# 4       1.0

# %%
# Get the sum of all the deaths
sum_of_deaths = covid_df["Death"].sum()

# %%
sum_of_deaths
# Out:
# 3172746830.0

# %%
# get the sum of cured patiets of arunachal pradesh 
cured_ap = pd.pivot_table(covid_df,values =["Cured/Discharged"], index = "Region", aggfunc = max)
cured_ap = cured_ap.sort_values(by = "Arunachal Pradesh", axis = 1)

# %%
cured_ap.head()
# Out:
#                              Cured/Discharged
# Region
# Andaman and Nicobar Islands            9986.0
# Andhra Pradesh                      2305893.0
# Arunachal Pradesh                     64218.0
# Assam                                716405.0
# Bihar                                819388.0

# %%
# get the data of a 10-04-2020 of all the regios
specific_date = covid_df["Date"].isin(["10-04-2020"])
covid_df[specific_date]
# Out:
#        S. No.        Date                       Region  Confirmed Cases  \
# 32         33  10-04-2020                        India             6412
# 830       831  10-04-2020  Andaman and Nicobar Islands               11
# 1643     1644  10-04-2020               Andhra Pradesh              348
# 2434     2435  10-04-2020            Arunachal Pradesh                1
# 3226     3227  10-04-2020                        Assam               29
# 4029     4030  10-04-2020                        Bihar               39
# 4835     4836  10-04-2020                   Chandigarh               18
# 5640     5641  10-04-2020                 Chhattisgarh               10
# 7208     7209  10-04-2020                        Delhi              720
# 8007     8008  10-04-2020                          Goa                7
# 8811     8812  10-04-2020                      Gujarat              241
# 9624     9625  10-04-2020                      Haryana              169
# ...

# %%
# get the data of ihar regio withi 05-02-2021 ad this 10-03-2021
filter1 = covid_df["Region"].isin(["Bihar"])
filter2 = covid_df["Date"].between("05-02-2021","10-03-2021")
covid_df[filter1 & filter2]
# Out:
#       S. No.        Date Region  Confirmed Cases  Active Cases  \
# 4024    4025  05-04-2020  Bihar               30          29.0
# 4025    4026  06-04-2020  Bihar               30          29.0
# 4026    4027  07-04-2020  Bihar               32          31.0
# 4027    4028  08-04-2020  Bihar               38          37.0
# 4028    4029  09-04-2020  Bihar               38          37.0
# ...      ...         ...    ...              ...           ...
# 4759    4760  08-05-2022  Bihar           830616          52.0
# 4785    4786  05-06-2022  Bihar           830823          69.0
# 4786    4787  06-06-2022  Bihar           830834          75.0
# 4787    4788  07-06-2022  Bihar           830838          74.0
# 4788    4789  09-06-2022  Bihar           830866          82.0
#
#       Cured/Discharged    Death
# 4024               0.0      1.0
# 4025               0.0      1.0
# 4026               0.0      1.0
# 4027               0.0      1.0
# 4028               0.0      1.0
# ...
